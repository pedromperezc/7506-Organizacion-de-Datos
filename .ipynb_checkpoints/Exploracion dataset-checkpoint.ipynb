# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
from pandas_profiling import ProfileReport
# %matplotlib inline

# %%
directorio = 'dataset'
archivo = 'Entrenamieto_ECI_2020.csv'
fname = os.path.join(directorio,archivo)
#De esta forma puedo filtrar columnas.
df = pd.read_csv(fname, parse_dates= ['Account_Created_Date','Delivery_Year', 
                                      'Quote_Expiry_Date', 'Month', 
                                      'Actual_Delivery_Date', 'Planned_Delivery_End_Date',
                                       'Planned_Delivery_Start_Date', 'Opportunity_Created_Date',
                                       'Last_Modified_Date'] )
df2 = pd.read_csv(fname)

# %%
df.head()
# Out:
#       ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0  27761      EMEA        None                                   1
# 1  27760      EMEA        None                                   0
# 2  27446  Americas  NW America                                   0
# 3  16808  Americas  NW America                                   1
# 4  16805  Americas  NW America                                   1
#
#    Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 0                                 1                             1
# 1                                 0                             0
# 2                                 0                             0
# 3                                 0                             1
# 4                                 0                             1
#
#    Bureaucratic_Code_0_Approved  Submitted_for_Approval    Bureaucratic_Code  \
# 0                             1                       0  Bureaucratic_Code_4
# ...

# %%
df.tail()
# Out:
#           ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 16942   8781      EMEA     Austria                                   1
# 16943   8786      EMEA     Austria                                   1
# 16944   8792      EMEA     Austria                                   1
# 16945  28561  Americas  NE America                                   1
# 16946  28318  Americas  NE America                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 16942                                 1                             1
# 16943                                 1                             1
# 16944                                 1                             1
# 16945                                 1                             1
# 16946                                 1                             1
#
#        Bureaucratic_Code_0_Approved  Submitted_for_Approval  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 52 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  16947 non-null  int64
#  1   Region                              16947 non-null  object
#  2   Territory                           16947 non-null  object
#  3   Pricing, Delivery_Terms_Quote_Appr  16947 non-null  int64
#  4   Pricing, Delivery_Terms_Approved    16947 non-null  int64
#  5   Bureaucratic_Code_0_Approval        16947 non-null  int64
#  6   Bureaucratic_Code_0_Approved        16947 non-null  int64
#  7   Submitted_for_Approval              16947 non-null  int64
#  8   Bureaucratic_Code                   16947 non-null  object
#  9   Account_Created_Date                16947 non-null  datetime64[ns]
#  10  Source                              16947 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Region', 'Territory', 'Pricing, Delivery_Terms_Quote_Appr',
#        'Pricing, Delivery_Terms_Approved', 'Bureaucratic_Code_0_Approval',
#        'Bureaucratic_Code_0_Approved', 'Submitted_for_Approval',
#        'Bureaucratic_Code', 'Account_Created_Date', 'Source ',
#        'Billing_Country', 'Account_Name', 'Opportunity_Name', 'Opportunity_ID',
#        'Sales_Contract_No', 'Account_Owner', 'Opportunity_Owner',
#        'Account_Type', 'Opportunity_Type', 'Quote_Type', 'Delivery_Terms',
#        'Opportunity_Created_Date', 'Brand', 'Product_Type', 'Size',
#        'Product_Category_B', 'Price', 'Currency', 'Last_Activity',
#        'Quote_Expiry_Date', 'Last_Modified_Date', 'Last_Modified_By',
#        'Product_Family', 'Product_Name', 'ASP_Currency', 'ASP',
#        'ASP_(converted)_Currency', 'ASP_(converted)',
#        'Planned_Delivery_Start_Date', 'Planned_Delivery_End_Date', 'Month',
#        'Delivery_Quarter', 'Delivery_Year', 'Actual_Delivery_Date', 'TRF',
# ...

# %%
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')

# %%
df['Total_Taxable_Amount'] = pd.to_numeric(df['Total_Taxable_Amount'], errors='coerce')

# %%
df['Total_Amount'] = pd.to_numeric(df['Total_Amount'], errors='coerce')

# %%
df.describe()
# Out:
#                  ID  Pricing, Delivery_Terms_Quote_Appr  \
# count  16947.000000                        16947.000000
# mean   17666.650440                            0.807990
# std     6940.859372                            0.393893
# min     4854.000000                            0.000000
# 25%    11953.000000                            1.000000
# 50%    18114.000000                            1.000000
# 75%    23845.500000                            1.000000
# max    28773.000000                            1.000000
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# count                      16947.000000                  16947.000000
# mean                           0.583584                      0.475482
# std                            0.492979                      0.499413
# min                            0.000000                      0.000000
# 25%                            0.000000                      0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16947 entries, 0 to 16946
# Data columns (total 52 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   ID                                  16947 non-null  int64
#  1   Region                              16947 non-null  object
#  2   Territory                           16947 non-null  object
#  3   Pricing, Delivery_Terms_Quote_Appr  16947 non-null  int64
#  4   Pricing, Delivery_Terms_Approved    16947 non-null  int64
#  5   Bureaucratic_Code_0_Approval        16947 non-null  int64
#  6   Bureaucratic_Code_0_Approved        16947 non-null  int64
#  7   Submitted_for_Approval              16947 non-null  int64
#  8   Bureaucratic_Code                   16947 non-null  object
#  9   Account_Created_Date                16947 non-null  datetime64[ns]
#  10  Source                              16947 non-null  object
# ...

# %%
#Borro la columna ya que no contiene ningún valor
df.drop(columns=['Actual_Delivery_Date'], inplace=True)

# %%
df.isnull().any()
# Out:
# ID                                    False
# Region                                False
# Territory                             False
# Pricing, Delivery_Terms_Quote_Appr    False
# Pricing, Delivery_Terms_Approved      False
# Bureaucratic_Code_0_Approval          False
# Bureaucratic_Code_0_Approved          False
# Submitted_for_Approval                False
# Bureaucratic_Code                     False
# Account_Created_Date                  False
# Source                                False
# Billing_Country                       False
# Account_Name                          False
# Opportunity_Name                      False
# Opportunity_ID                        False
# Sales_Contract_No                     False
# Account_Owner                         False
# Opportunity_Owner                     False
# Account_Type                          False
# Opportunity_Type                      False
# Quote_Type                            False
# ...

# %%
df.head()
# Out:
#       ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0  27761      EMEA        None                                   1
# 1  27760      EMEA        None                                   0
# 2  27446  Americas  NW America                                   0
# 3  16808  Americas  NW America                                   1
# 4  16805  Americas  NW America                                   1
#
#    Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 0                                 1                             1
# 1                                 0                             0
# 2                                 0                             0
# 3                                 0                             1
# 4                                 0                             1
#
#    Bureaucratic_Code_0_Approved  Submitted_for_Approval    Bureaucratic_Code  \
# 0                             1                       0  Bureaucratic_Code_4
# ...

# %%
df['Region'].value_counts()
# Out:
# Japan          4892
# EMEA           4664
# Americas       3945
# APAC           3262
# Middle East     184
# Name: Region, dtype: int64

# %%
df['Total_Amount'].describe()
# Out:
# count    1.688800e+04
# mean     1.993659e+06
# std      1.848426e+07
# min      0.000000e+00
# 25%      2.677500e+04
# 50%      1.072500e+05
# 75%      4.603898e+05
# max      1.320000e+09
# Name: Total_Amount, dtype: float64

# %%
(df['Total_Amount'] == 0).count()
# Out:
# 16947

# %%
df['Price'].describe()
# Out:
# count    356.000000
# mean       0.320323
# std        0.074717
# min        0.200000
# 25%        0.260000
# 50%        0.307500
# 75%        0.370000
# max        0.560000
# Name: Price, dtype: float64

# %%
(df['Price']==None).count()
# Out:
# 16947

# %%
df['Stage'].value_counts()
# Out:
# Closed Won       9533
# Closed Lost      7350
# Proposal           35
# Negotiation        18
# Qualification      11
# Name: Stage, dtype: int64

# %%
df['Product_Type'].value_counts()
# Out:
# None              15935
# Other               515
# Product_Type_3      179
# Product_Type_1      142
# Product_Type_0       94
# Product_Type_4       73
# Product_Type_2        9
# Name: Product_Type, dtype: int64

# %%
df['Product_Family'].value_counts()
# Out:
# Product_Family_77     1345
# Product_Family_133    1249
# Product_Family_132     763
# Product_Family_212     636
# Product_Family_100     619
#                       ...
# Product_Family_51        1
# Product_Family_34        1
# Product_Family_217       1
# Product_Family_55        1
# Product_Family_177       1
# Name: Product_Family, Length: 227, dtype: int64

# %%
df['Brand'].value_counts()
# Out:
# None        15911
# Other         607
# Brand_9       140
# Brand_5        48
# Brand_24       38
# Brand_11       34
# Brand_25       24
# Brand_10       22
# Brand_22       20
# Brand_13       17
# Brand_7        17
# Brand_21       17
# Brand_20       10
# Brand_23       10
# Brand_17        5
# Brand_27        5
# Brand_4         4
# Brand_2         4
# Brand_0         4
# Brand_12        3
# Brand_16        2
# Brand_26        1
# Brand_1         1
# Brand_6         1
# Brand_19        1
# Brand_3         1
# Name: Brand, dtype: int64

# %%
df['Source '].value_counts()
# Out:
# None         9497
# Source_7     2965
# Source_9     1459
# Source_11    1421
# Source_13     786
# Source_3      418
# Source_1      137
# Source_10     106
# Source_2       86
# Source_4       43
# Source_6       19
# Source_0        7
# Source_12       2
# Source_5        1
# Name: Source , dtype: int64

# %%
df['Source '].value_counts(normalize=True)
# Out:
# None         0.560394
# Source_7     0.174957
# Source_9     0.086092
# Source_11    0.083850
# Source_13    0.046380
# Source_3     0.024665
# Source_1     0.008084
# Source_10    0.006255
# Source_2     0.005075
# Source_4     0.002537
# Source_6     0.001121
# Source_0     0.000413
# Source_12    0.000118
# Source_5     0.000059
# Name: Source , dtype: float64

# %%
sns.stripplot(x="Total_Amount", y="Source ", data=df2)

# %%
df['Delivery_Year'].value_counts()
# Out:
# 2017-01-01    6318
# 2018-01-01    5830
# 2016-01-01    4371
# 2019-01-01     414
# 2020-01-01      14
# Name: Delivery_Year, dtype: int64

# %%
sns.relplot(x="Delivery_Year", y="Stage", data=df)

# %%
(df['Total_Amount']==0).value_counts()
# Out:
# False    16895
# True        52
# Name: Total_Amount, dtype: int64

# %%
perdidas = df[df['Stage'] == 'Closed Lost']
ganadas = df[df['Stage'] == 'Closed Won']
perdidas_mas_ganadas = pd.concat([perdidas, ganadas])

# %%
sns.stripplot(x="Stage", y="Total_Amount", data=perdidas_mas_ganadas)

# %%
df['Delivery_Year'].value_counts()
# Out:
# 2017-01-01    6318
# 2018-01-01    5830
# 2016-01-01    4371
# 2019-01-01     414
# 2020-01-01      14
# Name: Delivery_Year, dtype: int64

# %%
stage = ["Closed Lost", "Closed Won"]

sns.boxenplot(x="Stage", y="Total_Amount",
              color="b", order=stage,
              scale="linear", data=perdidas_mas_ganadas)

# %%
#Obtengo los 5 valores mayores
df.nlargest(5, 'Delivery_Year')
# Out:
#           ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 14819  14927      APAC   Indonesia                                   1
# 15219   8186     Japan        None                                   1
# 15220   8192     Japan        None                                   1
# 15324  13555  Americas  SE America                                   1
# 15784   9341     Japan       Japan                                   1
#
#        Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 14819                                 0                             1
# 15219                                 0                             1
# 15220                                 0                             1
# 15324                                 1                             1
# 15784                                 0                             1
#
#        Bureaucratic_Code_0_Approved  Submitted_for_Approval  \
# ...

# %%
df.nsmallest(5, 'Delivery_Year')
# Out:
#       ID    Region   Territory  Pricing, Delivery_Terms_Quote_Appr  \
# 0  27761      EMEA        None                                   1
# 1  27760      EMEA        None                                   0
# 2  27446  Americas  NW America                                   0
# 7  27455  Americas  NW America                                   1
# 8  24353     Japan        None                                   1
#
#    Pricing, Delivery_Terms_Approved  Bureaucratic_Code_0_Approval  \
# 0                                 1                             1
# 1                                 0                             0
# 2                                 0                             0
# 7                                 1                             1
# 8                                 0                             0
#
#    Bureaucratic_Code_0_Approved  Submitted_for_Approval    Bureaucratic_Code  \
# 0                             1                       0  Bureaucratic_Code_4
# ...

# %%
oportunidad_grouped = df.groupby(['Opportunity_ID', 'ASP_(converted)','Region', 'Stage']).agg({'Total_Amount':['mean', 'count', 'sum']}).reset_index()

# %%
oportunidad_grouped2 = df.groupby(['Opportunity_ID', 'ASP_(converted)','Region', 'Stage'])['Total_Amount'].sum().reset_index()

# %%
oportunidad_grouped2['total'] = oportunidad_grouped2['ASP_(converted)'] * oportunidad_grouped2['Total_Amount']

# %%
oportunidad_grouped2
# Out:
#        Opportunity_ID  ASP_(converted)    Region        Stage  Total_Amount  \
# 0                   0          0.58817      EMEA  Closed Lost    5272800.00
# 1                   1          0.59948      EMEA   Closed Won      48230.00
# 2                   2          0.48000  Americas   Closed Won      83865.60
# 3                   3          0.53000  Americas  Closed Lost    7421881.50
# 4                   4          0.53000  Americas  Closed Lost   13357192.50
# ...               ...              ...       ...          ...           ...
# 10868           12799          0.58251      EMEA   Closed Won     401700.00
# 10869           12800          0.53000  Americas  Closed Lost   21332500.00
# 10870           12801          0.58817      EMEA   Closed Won     299715.00
# 10871           12802          0.63750  Americas  Closed Lost    2346796.88
# 10872           12803          0.64000  Americas  Closed Lost   25603200.00
#
#               total
# 0      3.101303e+06
# ...

# %%
stage = ["Closed Lost", "Closed Won"]

sns.boxenplot(x="Stage", y="Total_Amount",
              color="b", order=stage,
              scale="linear", data=oportunidad_grouped2)

# %%
region_grouped = df.groupby(['Opportunity_ID','Region', 'Stage'])['Opportunity_Name'].count().reset_index()

# %%
region_grouped
# Out:
#       Opportunity_ID    Region        Stage  Opportunity_Name
# 0                  0      EMEA  Closed Lost                 1
# 1                  1      EMEA   Closed Won                 1
# 2                  2  Americas   Closed Won                 1
# 3                  3  Americas  Closed Lost                 1
# 4                  4  Americas  Closed Lost                 1
# ...              ...       ...          ...               ...
# 9836           12799      EMEA   Closed Won                 1
# 9837           12800  Americas  Closed Lost                 2
# 9838           12801      EMEA   Closed Won                 3
# 9839           12802  Americas  Closed Lost                 1
# 9840           12803  Americas  Closed Lost                 1
#
# [9841 rows x 4 columns]

# %%
region_grouped.columns = ['Opportunity_ID', 'Region', 'Stage', 'cantidad']

# %%
region_grouped = region_grouped.groupby(['Region', 'Stage'])['cantidad'].sum().reset_index()

# %%
region_grouped
# Out:
#          Region          Stage  cantidad
# 0          APAC    Closed Lost      1355
# 1          APAC     Closed Won      1896
# 2          APAC       Proposal         8
# 3          APAC  Qualification         3
# 4      Americas    Closed Lost      2140
# 5      Americas     Closed Won      1793
# 6      Americas    Negotiation         8
# 7      Americas       Proposal         4
# 8          EMEA    Closed Lost      2189
# 9          EMEA     Closed Won      2471
# 10         EMEA    Negotiation         1
# 11         EMEA       Proposal         3
# 12        Japan    Closed Lost      1546
# 13        Japan     Closed Won      3323
# 14        Japan    Negotiation         1
# 15        Japan       Proposal        14
# 16        Japan  Qualification         8
# 17  Middle East    Closed Lost       120
# 18  Middle East     Closed Won        50
# 19  Middle East    Negotiation         8
# 20  Middle East       Proposal         6

# %%
stage = ["EMEA", "Americas", "Japan", "Middle East"]

sns.boxenplot(x="Region", y="cantidad",
              color="b", order=stage,
              scale="linear", data=region_grouped)

# %%
stage_grouped = df.groupby('Stage')
