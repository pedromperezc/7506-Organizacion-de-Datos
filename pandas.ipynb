# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os

# %%
directorio = 'archive'
archivo = 'Oscars-demographics-DFE.csv'
fname = os.path.join(directorio,archivo)
#De esta forma puedo filtrar columnas.
df = pd.read_csv(fname, usecols= ['birthplace', 'date_of_birth', 'race_ethnicity', 'sexual_orientation', 'award', 'year_of_award','movie', 'person'], encoding= 'latin-1')

# %%
df = pd.read_csv(fname, encoding= 'latin-1')

# %%
df['person'].value_counts()
# Out:
# John Ford            4
# Katharine Hepburn    4
# Hilary Swank         4
# Jack Nicholson       3
# Meryl Streep         3
#                     ..
# William Holden       1
# Susan Hayward        1
# Al Pacino            1
# Lila Kedrova         1
# Charles Coburn       1
# Name: person, Length: 348, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 27 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   _unit_id                       441 non-null    int64
#  1   _golden                        441 non-null    bool
#  2   _unit_state                    441 non-null    object
#  3   _trusted_judgments             441 non-null    int64
#  4   _last_judgment_at              416 non-null    object
#  5   birthplace                     441 non-null    object
#  6   birthplace:confidence          441 non-null    float64
#  7   date_of_birth                  441 non-null    object
#  8   date_of_birth:confidence       441 non-null    float64
#  9   race_ethnicity                 441 non-null    object
#  10  race_ethnicity:confidence      441 non-null    float64
#  11  religion                       441 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['_unit_id', '_golden', '_unit_state', '_trusted_judgments',
#        '_last_judgment_at', 'birthplace', 'birthplace:confidence',
#        'date_of_birth', 'date_of_birth:confidence', 'race_ethnicity',
#        'race_ethnicity:confidence', 'religion', 'religion:confidence',
#        'sexual_orientation', 'sexual_orientation:confidence', 'year_of_award',
#        'year_of_award:confidence', 'award', 'biourl', 'birthplace_gold',
#        'date_of_birth_gold', 'movie', 'person', 'race_ethnicity_gold',
#        'religion_gold', 'sexual_orientation_gold', 'year_of_award_gold'],
#       dtype='object')

# %%
df.describe()
# Out:
#            _unit_id  _trusted_judgments  birthplace:confidence  \
# count  4.410000e+02          441.000000             441.000000
# mean   6.704825e+08            7.637188               0.995259
# std    1.139974e+05           19.015541               0.038917
# min    6.704544e+08            3.000000               0.657100
# 25%    6.704545e+08            3.000000               1.000000
# 50%    6.704546e+08            3.000000               1.000000
# 75%    6.704547e+08            3.000000               1.000000
# max    6.709729e+08           95.000000               1.000000
#
#        date_of_birth:confidence  race_ethnicity:confidence  \
# count                441.000000                 441.000000
# mean                   0.996607                   0.999130
# std                    0.032060                   0.016438
# min                    0.656200                   0.657100
# 25%                    1.000000                   1.000000
# ...

# %%
oscars_index = df.index
oscars_columns = df.columns
oscars_values = df.values

# %%
oscars_values
# Out:
# array([[670454353, False, 'finalized', ..., nan, nan, nan],
#        [670454354, False, 'finalized', ..., nan, nan, nan],
#        [670454355, False, 'finalized', ..., nan, nan, nan],
#        ...,
#        [670964912, False, 'finalized', ..., nan, nan, nan],
#        [670964956, False, 'finalized', ..., nan, nan, nan],
#        [670972898, False, 'finalized', ..., nan, nan, nan]], dtype=object)

# %%
type(oscars_values)
# Out:
# numpy.ndarray

# %%
df.dtypes
# Out:
# _unit_id                           int64
# _golden                             bool
# _unit_state                       object
# _trusted_judgments                 int64
# _last_judgment_at                 object
# birthplace                        object
# birthplace:confidence            float64
# date_of_birth                     object
# date_of_birth:confidence         float64
# race_ethnicity                    object
# race_ethnicity:confidence        float64
# religion                          object
# religion:confidence              float64
# sexual_orientation                object
# sexual_orientation:confidence    float64
# year_of_award                      int64
# year_of_award:confidence         float64
# award                             object
# biourl                            object
# birthplace_gold                   object
# date_of_birth_gold                object
# movie                             object
# person                            object
# ...

# %%
df.dtypes.value_counts()
# Out:
# object     16
# float64     7
# int64       3
# bool        1
# dtype: int64

# %%
df['person'].unique()
# Out:
# array(['Lewis Milestone', 'Frank Lloyd', 'Norman Taurog', 'Frank Borzage',
#        'Frank Capra', 'John Ford', 'Leo McCarey', 'Victor Fleming',
#        'William Wyler', 'Michael Curtiz', 'Jerome Robbins',
#        'Billy Wilder', 'Elia Kazan', 'John Huston',
#        'Joseph L. Mankiewicz', 'George Stevens', 'Fred Zinnemann',
#        'Delbert Mann', 'David Lean', 'Vincente Minnelli', 'Robert Wise',
#        'Tony Richardson', 'George Cukor', 'Mike Nichols', 'Joel Coen',
#        'Carol Reed', 'John Schlesinger', 'Franklin J. Schaffner',
#        'William Friedkin', 'Bob Fosse', 'George Roy Hill',
#        'Francis Ford Coppola', 'Milos Forman', 'John G. Avildsen',
#        'Woody Allen', 'Michael Cimino', 'Robert Benton', 'Robert Redford',
#        'Warren Beatty', 'Richard Attenborough', 'James L. Brooks',
#        'Sydney Pollack', 'Oliver Stone', 'Bernardo Bertolucci',
#        'Barry Levinson', 'Kevin Costner', 'Jonathan Demme',
# ...

# %%
# lo convierto en un dataframe con to_frame
type (df['person'].to_frame())
# Out:
# pandas.core.frame.DataFrame

# %%
df['person'].to_frame().info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   person  441 non-null    object
# dtypes: object(1)
# memory usage: 3.6+ KB

# %%
#Listar todos los metodos de una serie
(dir(pd.Series))
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
# ...

# %%
(dir(pd.DataFrame))
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
oscar_movie = df['movie']
oscar_year = df['year_of_award']

# %%
oscar_movie.head()
# Out:
# 0               Two Arabian Knights
# 1                   The Divine Lady
# 2    All Quiet on the Western Front
# 3                            Skippy
# 4                          Bad Girl
# Name: movie, dtype: object

# %%
oscar_movie.value_counts(normalize=True)
# Out:
# Million Dollar Baby            0.011338
# Network                        0.009070
# West Side Story                0.009070
# The Best Years of Our Lives    0.006803
# It Happened One Night          0.006803
#                                  ...
# True Grit                      0.002268
# The Untouchables               0.002268
# The Accidental Tourist         0.002268
# The Help                       0.002268
# Platoon                        0.002268
# Name: movie, Length: 336, dtype: float64

# %%
oscar_year.value_counts()
# Out:
# 1969    8
# 2005    7
# 1961    7
# 1999    7
# 2009    7
#        ..
# 1932    3
# 1931    3
# 1929    2
# 1933    1
# 1927    1
# Name: year_of_award, Length: 87, dtype: int64

# %%
#Total de elementos
df.size
# Out:
# 11907

# %%
#Dimension de la matriz
df.shape
# Out:
# (441, 27)

# %%
#Cantidad de filas
len(df)
# Out:
# 441

# %%
df.count()
# Out:
# _unit_id                         441
# _golden                          441
# _unit_state                      441
# _trusted_judgments               441
# _last_judgment_at                416
# birthplace                       441
# birthplace:confidence            441
# date_of_birth                    441
# date_of_birth:confidence         441
# race_ethnicity                   441
# race_ethnicity:confidence        441
# religion                         441
# religion:confidence              441
# sexual_orientation               441
# sexual_orientation:confidence    441
# year_of_award                    441
# year_of_award:confidence         441
# award                            441
# biourl                           441
# birthplace_gold                    9
# date_of_birth_gold                 8
# movie                            441
# person                           441
# race_ethnicity_gold                2
# religion_gold                     10
# ...

# %%
#Diferencia entra size, count y shape
#size nos da la dimensión
df['race_ethnicity_gold'].size
# Out:
# 441

# %%
#Counts nos devuelve el número de valores diferentes de null
# Solo tiene dos valores
df['race_ethnicity_gold'].count()
# Out:
# 2

# %%
#Serie de valores booleanos que termina los nulos
df['race_ethnicity_gold'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 436    True
# 437    True
# 438    True
# 439    True
# 440    True
# Name: race_ethnicity_gold, Length: 441, dtype: bool

# %%
#hasnan devuelve si existe o no valores nan, función solo para series
df['race_ethnicity_gold'].hasnans
# Out:
# True

# %%
#count se puede aplicar sobre un dataframe y devuelve el número de elementos.
df.count()
# Out:
# _unit_id                         441
# _golden                          441
# _unit_state                      441
# _trusted_judgments               441
# _last_judgment_at                416
# birthplace                       441
# birthplace:confidence            441
# date_of_birth                    441
# date_of_birth:confidence         441
# race_ethnicity                   441
# race_ethnicity:confidence        441
# religion                         441
# religion:confidence              441
# sexual_orientation               441
# sexual_orientation:confidence    441
# year_of_award                    441
# year_of_award:confidence         441
# award                            441
# biourl                           441
# birthplace_gold                    9
# date_of_birth_gold                 8
# movie                            441
# person                           441
# race_ethnicity_gold                2
# religion_gold                     10
# ...

# %%
#Podemos rellenar los valores null con algun valor por defecto.
oscar_race_ethnicity_gold_fillna = df['race_ethnicity_gold'].fillna('None')

# %%
oscar_race_ethnicity_gold_fillna.count()
# Out:
# 441

# %%
oscar_race_ethnicity_gold_fillna.size
# Out:
# 441

# %%
#Podemos eliminar las filas que continen nan
oscar_date_of_birth_droped = df['race_ethnicity_gold'].dropna()

# %%
oscar_date_of_birth_droped.count()
# Out:
# 2

# %%
oscar_date_of_birth_droped
# Out:
# 263    White
# 411    Black
# Name: race_ethnicity_gold, dtype: object

# %%
df['_trusted_judgments'].describe()
# Out:
# count    441.000000
# mean       7.637188
# std       19.015541
# min        3.000000
# 25%        3.000000
# 50%        3.000000
# 75%        3.000000
# max       95.000000
# Name: _trusted_judgments, dtype: float64

# %%
df['movie'].describe()
# Out:
# count                     441
# unique                    336
# top       Million Dollar Baby
# freq                        5
# Name: movie, dtype: object

# %%
df.describe()
# Out:
#            _unit_id  _trusted_judgments  birthplace:confidence  \
# count  4.410000e+02          441.000000             441.000000
# mean   6.704825e+08            7.637188               0.995259
# std    1.139974e+05           19.015541               0.038917
# min    6.704544e+08            3.000000               0.657100
# 25%    6.704545e+08            3.000000               1.000000
# 50%    6.704546e+08            3.000000               1.000000
# 75%    6.704547e+08            3.000000               1.000000
# max    6.709729e+08           95.000000               1.000000
#
#        date_of_birth:confidence  race_ethnicity:confidence  \
# count                441.000000                 441.000000
# mean                   0.996607                   0.999130
# std                    0.032060                   0.016438
# min                    0.656200                   0.657100
# 25%                    1.000000                   1.000000
# ...

# %%
#Puedo hacer operaciones sobre funciones:
df['_trusted_judgments'].min()/2
# Out:
# 1.5

# %%
df['_trusted_judgments']  + 2
# Out:
# 0      5
# 1      5
# 2      5
# 3      5
# 4      5
#       ..
# 436    5
# 437    5
# 438    5
# 439    5
# 440    5
# Name: _trusted_judgments, Length: 441, dtype: int64

# %%
#operadores logicos
(df['year_of_award'] == 1969).value_counts()
# Out:
# False    433
# True       8
# Name: year_of_award, dtype: int64

# %%
#Otra forma de aplicar operadores logicos eq = "==" | lt = "<" | gt = ">" | le = "<=" | eq = ">="
df['year_of_award'].eq(1969).value_counts()
# Out:
# False    433
# True       8
# Name: year_of_award, dtype: int64

# %%
#encadenamiento de metodos
df['date_of_birth_gold'].isnull().sum()
# Out:
# 433

# %%
df['date_of_birth_gold'].isnull().mean()
# Out:
# 0.981859410430839

# %%
#Separar una instrucción en lineas con barra inclinada:
df['date_of_birth_gold'].isnull()
    /.mean()

# %%
#Usando parentesis:
(df['date_of_birth_gold'].isnull()
    .mean())
# Out:
# 0.981859410430839

# %%
#Cleaning el Dataset
oscar = (pd.read_csv(fname, usecols= ['birthplace', 'date_of_birth', 'race_ethnicity', 'religion',
                                      'sexual_orientation', 'award', 'year_of_award','movie', 
                                      'person'], encoding= 'latin-1'))

# %%
print(len(oscar))
# Out:
# 441

# %%
oscar.info()
# Si quisiera elimanr nan en cualquier columna
oscar['birthplace'].dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 441 entries, 0 to 440
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   birthplace          441 non-null    object
#  1   date_of_birth       441 non-null    object
#  2   race_ethnicity      441 non-null    object
#  3   religion            441 non-null    object
#  4   sexual_orientation  441 non-null    object
#  5   year_of_award       441 non-null    int64
#  6   award               441 non-null    object
#  7   movie               441 non-null    object
#  8   person              441 non-null    object
# dtypes: int64(1), object(8)
# memory usage: 31.1+ KB
# 0        Chisinau, Moldova
# 1        Glasgow, Scotland
# 2        Chisinau, Moldova
# 3              Chicago, Il
# 4       Salt Lake City, Ut
#               ...
# 436        London, England
# 437    Manchester, England
# 438            Chicago, Il
# 439             Laurel, Ne
# ...

# %%
#Creo un indice
oscar_index = oscar.set_index(['person', 'year_of_award' ])

# %%
oscar_index
# Out:
#                                         birthplace date_of_birth  \
# person          year_of_award
# Lewis Milestone 1927             Chisinau, Moldova   30-Sep-1895
# Frank Lloyd     1930             Glasgow, Scotland    2-Feb-1886
# Lewis Milestone 1931             Chisinau, Moldova   30-Sep-1895
# Norman Taurog   1932                   Chicago, Il   23-Feb-1899
# Frank Borzage   1933            Salt Lake City, Ut   23-Apr-1894
# ...                                            ...           ...
# Rachel Weisz    2006               London, England      7-Mar-71
# Danny Boyle     2009           Manchester, England     20-Oct-56
# Jason Robards   1977                   Chicago, Il     26-Jul-22
# James Coburn    1999                    Laurel, Ne     31-Aug-28
# John Huston     1949                    Nevada, Mo      5-Aug-06
#
#                               race_ethnicity        religion  \
# person          year_of_award
# ...

# %%
oscar_index.count()
# Out:
# birthplace            441
# date_of_birth         441
# race_ethnicity        441
# religion              441
# sexual_orientation    441
# award                 441
# movie                 441
# dtype: int64

# %%
#Puedo establece las columnas y el indice al momento de leer el csv
df = pd.read_csv(fname, usecols= ['birthplace', 'date_of_birth', 'race_ethnicity', 'sexual_orientation', 'award', 'year_of_award','movie', 'person'], index_col=['person', 'year_of_award'], encoding= 'latin-1')

# %%
df.reset_index()
# Out:
#               person  year_of_award           birthplace date_of_birth  \
# 0    Lewis Milestone           1927    Chisinau, Moldova   30-Sep-1895
# 1        Frank Lloyd           1930    Glasgow, Scotland    2-Feb-1886
# 2    Lewis Milestone           1931    Chisinau, Moldova   30-Sep-1895
# 3      Norman Taurog           1932          Chicago, Il   23-Feb-1899
# 4      Frank Borzage           1933   Salt Lake City, Ut   23-Apr-1894
# ..               ...            ...                  ...           ...
# 436     Rachel Weisz           2006      London, England      7-Mar-71
# 437      Danny Boyle           2009  Manchester, England     20-Oct-56
# 438    Jason Robards           1977          Chicago, Il     26-Jul-22
# 439     James Coburn           1999           Laurel, Ne     31-Aug-28
# 440      John Huston           1949           Nevada, Mo      5-Aug-06
#
#     race_ethnicity sexual_orientation                    award  \
# ...

# %%
#Se puede eliminar el index devuelve las columnas 
df.reset_index()
# Out:
#               person  year_of_award           birthplace date_of_birth  \
# 0    Lewis Milestone           1927    Chisinau, Moldova   30-Sep-1895
# 1        Frank Lloyd           1930    Glasgow, Scotland    2-Feb-1886
# 2    Lewis Milestone           1931    Chisinau, Moldova   30-Sep-1895
# 3      Norman Taurog           1932          Chicago, Il   23-Feb-1899
# 4      Frank Borzage           1933   Salt Lake City, Ut   23-Apr-1894
# ..               ...            ...                  ...           ...
# 436     Rachel Weisz           2006      London, England      7-Mar-71
# 437      Danny Boyle           2009  Manchester, England     20-Oct-56
# 438    Jason Robards           1977          Chicago, Il     26-Jul-22
# 439     James Coburn           1999           Laurel, Ne     31-Aug-28
# 440      John Huston           1949           Nevada, Mo      5-Aug-06
#
#     race_ethnicity sexual_orientation                    award  \
# ...

# %%
#Puedo crear un index manteniendo las columnas del indice con drop=False
oscar_index = oscar.set_index(['person', 'year_of_award'], drop=False)

# %%
oscar_index
# Out:
#                                         birthplace date_of_birth  \
# person          year_of_award
# Lewis Milestone 1927             Chisinau, Moldova   30-Sep-1895
# Frank Lloyd     1930             Glasgow, Scotland    2-Feb-1886
# Lewis Milestone 1931             Chisinau, Moldova   30-Sep-1895
# Norman Taurog   1932                   Chicago, Il   23-Feb-1899
# Frank Borzage   1933            Salt Lake City, Ut   23-Apr-1894
# ...                                            ...           ...
# Rachel Weisz    2006               London, England      7-Mar-71
# Danny Boyle     2009           Manchester, England     20-Oct-56
# Jason Robards   1977                   Chicago, Il     26-Jul-22
# James Coburn    1999                    Laurel, Ne     31-Aug-28
# John Huston     1949                    Nevada, Mo      5-Aug-06
#
#                               race_ethnicity        religion  \
# person          year_of_award
# ...

# %%
oscar_by_id = pd.read_csv(fname, usecols= ['birthplace', 'date_of_birth', 'race_ethnicity', 'sexual_orientation', 'award', 'year_of_award','movie', 'person'], encoding= 'latin-1')

# %%
#creo el indice
oscar_by_id = oscar_by_id.set_index(['person', 'year_of_award'], drop=False)

# %%
oscar_by_id.head()
# Out:
#                                        birthplace date_of_birth  \
# person          year_of_award
# Lewis Milestone 1927            Chisinau, Moldova   30-Sep-1895
# Frank Lloyd     1930            Glasgow, Scotland    2-Feb-1886
# Lewis Milestone 1931            Chisinau, Moldova   30-Sep-1895
# Norman Taurog   1932                  Chicago, Il   23-Feb-1899
# Frank Borzage   1933           Salt Lake City, Ut   23-Apr-1894
#
#                               race_ethnicity sexual_orientation  \
# person          year_of_award
# Lewis Milestone 1927                   White           Straight
# Frank Lloyd     1930                   White           Straight
# Lewis Milestone 1931                   White           Straight
# Norman Taurog   1932                   White           Straight
# Frank Borzage   1933                   White           Straight
#
#                                year_of_award          award  \
# person          year_of_award
# ...

# %%
#Renobrar tanto valores de registros como nombres de columnas
idx_rename = {'Lewis Milestone':'L Milestone'}
col_rename = {'birthplace':'nacimiento', 'race_ethnicity':'raza'}

oscar_by_id = oscar_by_id.rename(index= idx_rename, columns=col_rename)

# %%
oscar_by_id.head()
# Out:
#                                      nacimiento date_of_birth   raza  \
# person        year_of_award
# L Milestone   1927            Chisinau, Moldova   30-Sep-1895  White
# Frank Lloyd   1930            Glasgow, Scotland    2-Feb-1886  White
# L Milestone   1931            Chisinau, Moldova   30-Sep-1895  White
# Norman Taurog 1932                  Chicago, Il   23-Feb-1899  White
# Frank Borzage 1933           Salt Lake City, Ut   23-Apr-1894  White
#
#                             sexual_orientation  year_of_award          award  \
# person        year_of_award
# L Milestone   1927                    Straight           1927  Best Director
# Frank Lloyd   1930                    Straight           1930  Best Director
# L Milestone   1931                    Straight           1931  Best Director
# Norman Taurog 1932                    Straight           1932  Best Director
# Frank Borzage 1933                    Straight           1933  Best Director
#
# ...

# %%
oscar_by_id['person'].describe()
# Out:
# count           441
# unique          348
# top       John Ford
# freq              4
# Name: person, dtype: object

# %%
oscar_by_id.loc[['John Ford']]
# Out:
#                                  nacimiento date_of_birth   raza  \
# person    year_of_award
# John Ford 1936           Cape Elizabeth, Me    1-Feb-1894  White
#           1941           Cape Elizabeth, Me    1-Feb-1894  White
#           1942           Cape Elizabeth, Me    1-Feb-1894  White
#           1953           Cape Elizabeth, Me    1-Feb-1894  White
#
#                         sexual_orientation  year_of_award          award  \
# person    year_of_award
# John Ford 1936                    Bisexual           1936  Best Director
#           1941                    Bisexual           1941  Best Director
#           1942                    Bisexual           1942  Best Director
#           1953                    Bisexual           1953  Best Director
#
#                                            movie     person
# person    year_of_award
# John Ford 1936                      The Informer  John Ford
#           1941               The Grapes of Wrath  John Ford
# ...

# %%
#obtengo la lista de columnas y la convertimos en una lista
oscar_columns = oscar_by_id.columns.to_list()

# %%
oscar_columns
# Out:
# ['nacimiento',
#  'date_of_birth',
#  'raza',
#  'sexual_orientation',
#  'year_of_award',
#  'award',
#  'movie',
#  'person']

# %%
oscar_columns[1] = 'fecha_nacimiento'

# %%
#Puedo modificar las columnas del data frame directamente a travpes de una lista
oscar_by_id.columns = oscar_columns

# %%
oscar_by_id.head()
# Out:
#                                      nacimiento fecha_nacimiento   raza  \
# person        year_of_award
# L Milestone   1927            Chisinau, Moldova      30-Sep-1895  White
# Frank Lloyd   1930            Glasgow, Scotland       2-Feb-1886  White
# L Milestone   1931            Chisinau, Moldova      30-Sep-1895  White
# Norman Taurog 1932                  Chicago, Il      23-Feb-1899  White
# Frank Borzage 1933           Salt Lake City, Ut      23-Apr-1894  White
#
#                             sexual_orientation  year_of_award          award  \
# person        year_of_award
# L Milestone   1927                    Straight           1927  Best Director
# Frank Lloyd   1930                    Straight           1930  Best Director
# L Milestone   1931                    Straight           1931  Best Director
# Norman Taurog 1932                    Straight           1932  Best Director
# Frank Borzage 1933                    Straight           1933  Best Director
#
# ...

# %%
oscar_by_id['promedio'] = 0

# %%
oscar_by_id = oscar_by_id.rename(columns={'promedio':'last_10_years'})

# %%
oscar_by_id.head(2)
# Out:
#                                   nacimiento fecha_nacimiento   raza  \
# person      year_of_award
# L Milestone 1927           Chisinau, Moldova      30-Sep-1895  White
# Frank Lloyd 1930           Glasgow, Scotland       2-Feb-1886  White
#
#                           sexual_orientation  year_of_award          award  \
# person      year_of_award
# L Milestone 1927                    Straight           1927  Best Director
# Frank Lloyd 1930                    Straight           1930  Best Director
#
#                                          movie           person  last_10_years
# person      year_of_award
# L Milestone 1927           Two Arabian Knights  Lewis Milestone              0
# Frank Lloyd 1930               The Divine Lady      Frank Lloyd              0

# %%
oscar_by_id['last_10_years'] = oscar_by_id['year_of_award'] >= 2010

# %%
oscar_by_id
# Out:
#                                       nacimiento fecha_nacimiento   raza  \
# person        year_of_award
# L Milestone   1927             Chisinau, Moldova      30-Sep-1895  White
# Frank Lloyd   1930             Glasgow, Scotland       2-Feb-1886  White
# L Milestone   1931             Chisinau, Moldova      30-Sep-1895  White
# Norman Taurog 1932                   Chicago, Il      23-Feb-1899  White
# Frank Borzage 1933            Salt Lake City, Ut      23-Apr-1894  White
# ...                                          ...              ...    ...
# Rachel Weisz  2006               London, England         7-Mar-71  White
# Danny Boyle   2009           Manchester, England        20-Oct-56  White
# Jason Robards 1977                   Chicago, Il        26-Jul-22  White
# James Coburn  1999                    Laurel, Ne        31-Aug-28  White
# John Huston   1949                    Nevada, Mo         5-Aug-06  White
#
# ...

# %%
oscar_by_id['last_10_years'].value_counts()
# Out:
# False    417
# True      24
# Name: last_10_years, dtype: int64

# %%
#Borrar una columna | implace significa que modifica el dataframe
oscar_by_id.drop(columns=['last_10_years'], inplace=True)

# %%
oscar_by_id.head(2)
# Out:
#                                   nacimiento fecha_nacimiento   raza  \
# person      year_of_award
# L Milestone 1927           Chisinau, Moldova      30-Sep-1895  White
# Frank Lloyd 1930           Glasgow, Scotland       2-Feb-1886  White
#
#                           sexual_orientation  year_of_award          award  \
# person      year_of_award
# L Milestone 1927                    Straight           1927  Best Director
# Frank Lloyd 1930                    Straight           1930  Best Director
#
#                                          movie           person
# person      year_of_award
# L Milestone 1927           Two Arabian Knights  Lewis Milestone
# Frank Lloyd 1930               The Divine Lady      Frank Lloyd

# %%
#Obtener la posicion de una columna
oscar_by_id.columns.get_loc('raza')
# Out:
# 2

# %%
#Ahora puedo inserta una columna en esa posición
posicion = oscar_by_id.columns.get_loc('raza') + 1
oscar_by_id.insert(loc=posicion, column='last_30_years', value= (oscar_by_id['year_of_award'] >= 1990))

# %%
oscar_by_id.tail()
# Out:
#                                       nacimiento fecha_nacimiento   raza  \
# person        year_of_award
# Rachel Weisz  2006               London, England         7-Mar-71  White
# Danny Boyle   2009           Manchester, England        20-Oct-56  White
# Jason Robards 1977                   Chicago, Il        26-Jul-22  White
# James Coburn  1999                    Laurel, Ne        31-Aug-28  White
# John Huston   1949                    Nevada, Mo         5-Aug-06  White
#
#                              last_30_years  last_20_years  last_5_years  \
# person        year_of_award
# Rachel Weisz  2006                    True           True         False
# Danny Boyle   2009                    True           True         False
# Jason Robards 1977                   False          False         False
# James Coburn  1999                    True          False         False
# John Huston   1949                   False          False         False
#
# ...

# %%
#otra forma de borrar una columna es a través de del
del oscar_by_id['last_30_years']

# %%
oscar_by_id.head()
# Out:
#                                      nacimiento fecha_nacimiento   raza  \
# person        year_of_award
# L Milestone   1927            Chisinau, Moldova      30-Sep-1895  White
# Frank Lloyd   1930            Glasgow, Scotland       2-Feb-1886  White
# L Milestone   1931            Chisinau, Moldova      30-Sep-1895  White
# Norman Taurog 1932                  Chicago, Il      23-Feb-1899  White
# Frank Borzage 1933           Salt Lake City, Ut      23-Apr-1894  White
#
#                              last_20_years  last_5_years  last_10_years  \
# person        year_of_award
# L Milestone   1927                   False         False          False
# Frank Lloyd   1930                   False         False          False
# L Milestone   1931                   False         False          False
# Norman Taurog 1932                   False         False          False
# Frank Borzage 1933                   False         False          False
#
# ...

# %%
oscar_by_id.dtypes.value_counts()
# Out:
# object    7
# bool      3
# int64     1
# dtype: int64

# %%
oscar_by_id['fecha_nacimiento'] = pd.to_datetime(oscar_by_id['fecha_nacimiento'], errors='coerce')

# %%
oscar_by_id.dtypes.value_counts()
# Out:
# object            6
# bool              3
# datetime64[ns]    1
# int64             1
# dtype: int64

# %%
#Con select_dtypes puedo seleccionar las columnas con un determinado tipo de dato
oscar_by_id.select_dtypes(include=['int64', 'bool']).head(2)
# Out:
#                            last_20_years  last_5_years  last_10_years  \
# person      year_of_award
# L Milestone 1927                   False         False          False
# Frank Lloyd 1930                   False         False          False
#
#                            year_of_award
# person      year_of_award
# L Milestone 1927                    1927
# Frank Lloyd 1930                    1930

# %%
#Puedo filtrar por nombre de columna
oscar_by_id.filter(like='last')
# Out:
#                              last_20_years  last_5_years  last_10_years
# person        year_of_award
# L Milestone   1927                   False         False          False
# Frank Lloyd   1930                   False         False          False
# L Milestone   1931                   False         False          False
# Norman Taurog 1932                   False         False          False
# Frank Borzage 1933                   False         False          False
# ...                                    ...           ...            ...
# Rachel Weisz  2006                    True         False          False
# Danny Boyle   2009                    True         False          False
# Jason Robards 1977                   False         False          False
# James Coburn  1999                   False         False          False
# John Huston   1949                   False         False          False
#
# [441 rows x 3 columns]

# %%
#Puedo buscar con expresiones regulares
oscar_by_id.filter(regex='_')
# Out:
#                             fecha_nacimiento  last_20_years  last_5_years  \
# person        year_of_award
# L Milestone   1927                1895-09-30          False         False
# Frank Lloyd   1930                1886-02-02          False         False
# L Milestone   1931                1895-09-30          False         False
# Norman Taurog 1932                1899-02-23          False         False
# Frank Borzage 1933                1894-04-23          False         False
# ...                                      ...            ...           ...
# Rachel Weisz  2006                1971-03-07           True         False
# Danny Boyle   2009                2056-10-20           True         False
# Jason Robards 1977                2022-07-26          False         False
# James Coburn  1999                2028-08-31          False         False
# John Huston   1949                2006-08-05          False         False
#
# ...

# %%
#Se puede también filtrar por nombre
oscar_by_id.filter(items=['last_20_years', 'last_5_years'])
# Out:
#                              last_20_years  last_5_years
# person        year_of_award
# L Milestone   1927                   False         False
# Frank Lloyd   1930                   False         False
# L Milestone   1931                   False         False
# Norman Taurog 1932                   False         False
# Frank Borzage 1933                   False         False
# ...                                    ...           ...
# Rachel Weisz  2006                    True         False
# Danny Boyle   2009                    True         False
# Jason Robards 1977                   False         False
# James Coburn  1999                   False         False
# John Huston   1949                   False         False
#
# [441 rows x 2 columns]

# %%
#Puedo ordenar las columnas
oscar_by_id.columns
# Out:
# Index(['nacimiento', 'fecha_nacimiento', 'raza', 'last_20_years',
#        'last_5_years', 'last_10_years', 'sexual_orientation', 'year_of_award',
#        'award', 'movie', 'person'],
#       dtype='object')

# %%
nuevo_orden = ['person','nacimiento', 'fecha_nacimiento', 'raza', 'last_20_years',
       'last_5_years', 'last_10_years', 'sexual_orientation', 'year_of_award',
       'award', 'movie']
oscar_by_id = oscar_by_id[nuevo_orden]

# %%
oscar_by_id
# Out:
#                                       person           nacimiento  \
# person        year_of_award
# L Milestone   1927           Lewis Milestone    Chisinau, Moldova
# Frank Lloyd   1930               Frank Lloyd    Glasgow, Scotland
# L Milestone   1931           Lewis Milestone    Chisinau, Moldova
# Norman Taurog 1932             Norman Taurog          Chicago, Il
# Frank Borzage 1933             Frank Borzage   Salt Lake City, Ut
# ...                                      ...                  ...
# Rachel Weisz  2006              Rachel Weisz      London, England
# Danny Boyle   2009               Danny Boyle  Manchester, England
# Jason Robards 1977             Jason Robards          Chicago, Il
# James Coburn  1999              James Coburn           Laurel, Ne
# John Huston   1949               John Huston           Nevada, Mo
#
#                             fecha_nacimiento   raza  last_20_years  \
# person        year_of_award
# ...

# %%
oscar_by_id = pd.read_csv(fname, usecols= ['birthplace', 'date_of_birth', 'race_ethnicity',
                                           'sexual_orientation', 'award', 'year_of_award'
                                           ,'movie', 'person'], encoding= 'latin-1')

# %%
#Rango
oscar_by_id.iloc[0:5]
# Out:
#            birthplace date_of_birth race_ethnicity sexual_orientation  \
# 0   Chisinau, Moldova   30-Sep-1895          White           Straight
# 1   Glasgow, Scotland    2-Feb-1886          White           Straight
# 2   Chisinau, Moldova   30-Sep-1895          White           Straight
# 3         Chicago, Il   23-Feb-1899          White           Straight
# 4  Salt Lake City, Ut   23-Apr-1894          White           Straight
#
#    year_of_award          award                           movie  \
# 0           1927  Best Director             Two Arabian Knights
# 1           1930  Best Director                 The Divine Lady
# 2           1931  Best Director  All Quiet on the Western Front
# 3           1932  Best Director                          Skippy
# 4           1933  Best Director                        Bad Girl
#
#             person
# 0  Lewis Milestone
# 1      Frank Lloyd
# 2  Lewis Milestone
# 3    Norman Taurog
# 4    Frank Borzage

# %%
#Rango con step
oscar_by_id.iloc[0:10:3]
# Out:
#                   birthplace date_of_birth race_ethnicity sexual_orientation  \
# 0          Chisinau, Moldova   30-Sep-1895          White           Straight
# 3                Chicago, Il   23-Feb-1899          White           Straight
# 6  Bisacquino, Sicily, Italy   18-May-1897          White           Straight
# 9            Los Angeles, Ca    3-Oct-1898          White           Straight
#
#    year_of_award          award                  movie           person
# 0           1927  Best Director    Two Arabian Knights  Lewis Milestone
# 3           1932  Best Director                 Skippy    Norman Taurog
# 6           1935  Best Director  It Happened One Night      Frank Capra
# 9           1938  Best Director        The Awful Truth      Leo McCarey

# %%
#Con loc podemos listar a través de una lista:
oscar_by_id.loc[[0,2,3,5,10]]
# Out:
#                    birthplace date_of_birth race_ethnicity sexual_orientation  \
# 0           Chisinau, Moldova   30-Sep-1895          White           Straight
# 2           Chisinau, Moldova   30-Sep-1895          White           Straight
# 3                 Chicago, Il   23-Feb-1899          White           Straight
# 5           Glasgow, Scotland    2-Feb-1886          White           Straight
# 10  Bisacquino, Sicily, Italy   18-May-1897          White           Straight
#
#     year_of_award          award                           movie  \
# 0            1927  Best Director             Two Arabian Knights
# 2            1931  Best Director  All Quiet on the Western Front
# 3            1932  Best Director                          Skippy
# 5            1934  Best Director                       Cavalcade
# 10           1939  Best Director      You Can't Take It with You
#
#              person
# 0   Lewis Milestone
# 2   Lewis Milestone
# 3     Norman Taurog
# ...

# %%
#Seleccionar fila y columna con iloc
oscar_by_id.iloc[0,5]
# Out:
# 'Best Director'

# %%
oscar_by_id.iloc[0:5,3:5]
# Out:
#   sexual_orientation  year_of_award
# 0           Straight           1927
# 1           Straight           1930
# 2           Straight           1931
# 3           Straight           1932
# 4           Straight           1933

# %%
#Seecciono todos los registros y las columas es una lista
oscar_by_id.iloc[:,[1,3]]
# Out:
#     date_of_birth sexual_orientation
# 0     30-Sep-1895           Straight
# 1      2-Feb-1886           Straight
# 2     30-Sep-1895           Straight
# 3     23-Feb-1899           Straight
# 4     23-Apr-1894           Straight
# ..            ...                ...
# 436      7-Mar-71           Straight
# 437     20-Oct-56           Straight
# 438     26-Jul-22           Straight
# 439     31-Aug-28           Straight
# 440      5-Aug-06           Straight
#
# [441 rows x 2 columns]

# %%
#loc permite ingresar las columas a través de una lista
oscar_by_id.loc[:, ['person', 'date_of_birth', 'sexual_orientation']]
# Out:
#               person date_of_birth sexual_orientation
# 0    Lewis Milestone   30-Sep-1895           Straight
# 1        Frank Lloyd    2-Feb-1886           Straight
# 2    Lewis Milestone   30-Sep-1895           Straight
# 3      Norman Taurog   23-Feb-1899           Straight
# 4      Frank Borzage   23-Apr-1894           Straight
# ..               ...           ...                ...
# 436     Rachel Weisz      7-Mar-71           Straight
# 437      Danny Boyle     20-Oct-56           Straight
# 438    Jason Robards     26-Jul-22           Straight
# 439     James Coburn     31-Aug-28           Straight
# 440      John Huston      5-Aug-06           Straight
#
# [441 rows x 3 columns]

# %%
oscar_last_20_years = oscar_by_id['year_of_award'] >= 2010

# %%
oscar_last_20_years.sum()
# Out:
# 24

# %%
oscar_last_20_years.mean() * 100
# Out:
# 5.442176870748299

# %%
oscar_last_20_years.value_counts()
# Out:
# False    417
# True      24
# Name: year_of_award, dtype: int64

# %%
oscar_best_director = oscar_by_id['award'] == 'Best Director'

# %%
oscar_best_director.value_counts()
# Out:
# False    350
# True      91
# Name: award, dtype: int64

# %%
(oscar_last_20_years & oscar_best_director).value_counts()
# Out:
# False    438
# True       3
# dtype: int64

# %%
# Selecciono solo los registros que son true
oscar_by_id[oscar_last_20_years]
# Out:
#                                   birthplace date_of_birth race_ethnicity  \
# 84                           London, England          1972          White
# 85                             Paris, France     29-Mar-67          White
# 86                          Pingtung, Taiwan     23-Oct-54          Asian
# 168                          Los Angeles, Ca      4-Dec-49          White
# 169            Grayshott, Hampshire, England     10-Sep-60          White
# 170  Rueil-Malmaison, Hauts-De-Seine, France     19-Jun-72          White
# 171                          London, England     29-Apr-57          White
# 172                               Uvalde, Tx      4-Nov-69          White
# 246                                       Na      4-Oct-56          White
# 247      Haverfordwest, Pembrokeshire, Wales     30-Jan-74          White
# 248                 Toronto, Ontario, Canada     13-Dec-29          White
# 249                                       Na      4-Oct-56          White
# ...

# %%
oscar_by_id[oscar_best_director]
# Out:
#                   birthplace date_of_birth race_ethnicity sexual_orientation  \
# 0          Chisinau, Moldova   30-Sep-1895          White           Straight
# 1          Glasgow, Scotland    2-Feb-1886          White           Straight
# 2          Chisinau, Moldova   30-Sep-1895          White           Straight
# 3                Chicago, Il   23-Feb-1899          White           Straight
# 4         Salt Lake City, Ut   23-Apr-1894          White           Straight
# ..                       ...           ...            ...                ...
# 86          Pingtung, Taiwan     23-Oct-54          Asian           Straight
# 416  Sucha, Galicia, Austria     22-Jun-06          White           Straight
# 419            New York City      3-Feb-39          White           Straight
# 437      Manchester, England     20-Oct-56          White           Straight
# 440               Nevada, Mo      5-Aug-06          White           Straight
#
# ...

# %%
oscar_by_id[oscar_last_20_years & oscar_best_director]
# Out:
#           birthplace date_of_birth race_ethnicity sexual_orientation  \
# 84   London, England          1972          White                 Na
# 85     Paris, France     29-Mar-67          White           Straight
# 86  Pingtung, Taiwan     23-Oct-54          Asian           Straight
#
#     year_of_award          award              movie               person
# 84           2011  Best Director  The King's Speech           Tom Hooper
# 85           2012  Best Director         The Artist  Michel Hazanavicius
# 86           2013  Best Director         Life of Pi              Ang Lee
